# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import os

# %%
url = "http://www.fifa.com/worldcup/archive/brazil2014/index.html"

# %%
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')

# %%
tokens = [(op.attrs['value'][:-10]) for op in soup.find_all('option')[1:]]
tokens
# Out:
# ['/worldcup/archive/brazil2014/',
#  '/worldcup/archive/southafrica2010/',
#  '/worldcup/archive/germany2006/',
#  '/worldcup/archive/koreajapan2002/',
#  '/worldcup/archive/france1998/',
#  '/worldcup/archive/usa1994/',
#  '/worldcup/archive/italy1990/',
#  '/worldcup/archive/mexico1986/',
#  '/worldcup/archive/spain1982/',
#  '/worldcup/archive/argentina1978/',
#  '/worldcup/archive/germany1974/',
#  '/worldcup/archive/mexico1970/',
#  '/worldcup/archive/england1966/',
#  '/worldcup/archive/chile1962/',
#  '/worldcup/archive/sweden1958/',
#  '/worldcup/archive/switzerland1954/',
#  '/worldcup/archive/brazil1950/',
#  '/worldcup/archive/france1938/',
#  '/worldcup/archive/italy1934/',
#  '/worldcup/archive/uruguay1930/']

# %% [markdown]
# ## Create directory for storing results

# %%
PATH = 'World-Cup-DataBase'

# %%
"""/italy1934/ -> /1934--italy/"""
def parse_names(token):
    token = token [1:-1]
    return '/' + token[-4:] + '--' + token[:-4] + '/'

# %%
"""Create directory"""

for token in tokens:
    directory = PATH + parse_names(token[17:]) +'statistics'
    if not os.path.exists(directory):
        os.makedirs(directory)
    directory = PATH + parse_names(token[17:]) +'matches'
    if not os.path.exists(directory):
        os.makedirs(directory)
    directory = PATH + parse_names(token[17:]) +'teams'
    if not os.path.exists(directory):
        os.makedirs(directory)

# %% [markdown]
# # 1. Statistics

# %% [markdown]
# ## Player top goals

# %%
"""Value to be extracted: CountryCodes, Players, Goals, MinutesPlayed, MatchesPlayed"""
def player_top_goals():
    for token in tokens:
        URL = 'http://www.fifa.com' + token + 'statistics/players/goal-scored.html'
        Countries = []
        Players = []
        Goals = []
        Minutes = []
        Matches = []
        r = requests.get(URL)
        soup = BeautifulSoup(r.text, 'html.parser')
        table = soup.findChildren('table')[0]
        rows = table.findChildren(['tr'])
        
        for row in rows[1:]:
            Countries.append(row.findAll('td', {'class': 'tbl-playername teamname-nolink'})[0].img['alt'])
            Players  .append(row.findAll('td', {'class': 'tbl-playername teamname-nolink'})[0].text)  
            Minutes  .append(row.findAll('td', {'class': 'tbl-minp'})[0].text)
            Goals    .append(row.findAll('td', {'class': 'tbl-goalfor'})[0].text)
            Matches  .append(row.findAll('td', {'class': 'tbl-mp'})[0].text)

        df = pd.DataFrame({
                'CountryCode': Countries,
                'Player': Players,
                'Goals': Goals,
                'MinutesPlayed': Minutes,
                'MatchesPlayed': Matches
        })
        
        directory = PATH + parse_names(token[17:]) + 'statistics/'
        df.to_csv(directory + 'player_top_goals.csv', index=False)
        
player_top_goals()

# %% [markdown]
# ## Team top goals

# %%
"""Value to be extracted: Country, CountryCode, Goals, GoalsAgainst, MatchesPlayed"""
def team_top_goals():
    for token in tokens:
        URL = 'http://www.fifa.com' + token + 'statistics/teams/goal-scored.html'
        Countries = []
        CountryCodes = []
        Goals = []
        GoalsAg = []
        Matches = []
        r = requests.get(URL)
        soup = BeautifulSoup(r.text, 'html.parser')
        table = soup.findChildren('table')[0]
        rows = table.findChildren(['tr'])
        for row in rows[1:]:
            country = row.findAll('span', {'class': 't-nText'})[0].text
            if 'Ivoire' in country:
                country = 'Ivory Coast'
            Countries   .append(country)
            CountryCodes.append(row.findAll('span', {'class': 't-nTri'})[0].text)
            Goals       .append(row.findAll('td', {'class': 'tbl-goalfor'})[0].text)
            GoalsAg     .append(row.findAll('td', {'class': 'tbl-goalagainst'})[0].text)
            Matches     .append(row.findAll('td', {'class': 'tbl-mp'})[0].text)
        #A special case for CANADA in 1986
        #The result of CANADA (team top goals) is not showed in the website
        #http://www.fifa.com/worldcup/archive/mexico1986/statistics/teams/goal-scored.html
        if (token[-5:-1]=='1986'):
            Countries   .append('Canada')
            CountryCodes.append('CAN')
            Goals       .append('0')
            GoalsAg     .append('5')
            Matches     .append('3')
        #Same here for TRINIDAD AND TOBAGO at 2006
        if (token[-5:-1]=='2006'):
            Countries   .append('Trinidad and Tobago')
            CountryCodes.append('TRI')
            Goals       .append('0')
            GoalsAg     .append('4')
            Matches     .append('3')
        df = pd.DataFrame({
                'Country': Countries,
                'CountryCode' : CountryCodes,
                'Goals': Goals,
                'GoalsAgainst' : GoalsAg,
                'MatchesPlayed': Matches
        })
        
        directory = PATH + parse_names(token[17:]) + 'statistics/'
        df.to_csv(directory + 'team_top_goals.csv', index=False)
        
team_top_goals()

# %% [markdown]
# ## Player top cards

# %%
"""Value to be extracted: CountryCodes, Players, Yellow Cards, Red Cards, MatchesPlayed"""
def player_top_cards():
    for token in tokens:
        URL = 'http://www.fifa.com' + token + 'statistics/players/disciplinary.html'
        Countries = []
        Players = []
        Yellows = []
        Reds = []
        Matches = []
        r = requests.get(URL)
        soup = BeautifulSoup(r.text, 'html.parser')
        table = soup.findChildren('table')[0]
        rows = table.findChildren(['tr'])
        for row in rows[1:]:
            
            Countries.append(row.findAll('td', {'class': 'tbl-playername teamname-nolink'})[0].img['alt'])
            Players  .append(row.findAll('td', {'class': 'tbl-playername teamname-nolink'})[0].text)  
            Yellows  .append(row.findAll('td', {'class': 'tbl-yc'})[0].text)
            Reds     .append(row.findAll('td', {'class': 'tbl-rc'})[0].text)
            Matches  .append(row.findAll('td', {'class': 'tbl-mp'})[0].text)

        df = pd.DataFrame({
                'CountryCode': Countries,
                'Player': Players,
                'YellowCards': Yellows,
                'RedCards': Reds,
                'MatchesPlayed': Matches
        })
        
        directory = PATH + parse_names(token[17:]) + 'statistics/'
        df.to_csv(directory + 'player_top_cards.csv', index=False)
        
player_top_cards()

# %% [markdown]
# ## Team top cards

# %%
"""Value to be extracted: Country, Country Code, Yellow Cards, Red Cards, MatchesPlayed"""
def team_top_cards():
    for token in tokens:
        URL = 'http://www.fifa.com' + token + 'statistics/teams/disciplinary.html'
        Countries = []
        CountryCodes = []
        Yellows = []
        Reds = []
        Matches = []
        r = requests.get(URL)
        soup = BeautifulSoup(r.text, 'html.parser')
        table = soup.findChildren('table')[0]
        rows = table.findChildren(['tr'])
        for row in rows[1:]:
            country = row.findAll('span', {'class': 't-nText'})[0].text
            if 'Ivoire' in country:
                country = 'Ivory Coast'
            Countries   .append(country)
            CountryCodes.append(row.findAll('span', {'class': 't-nTri'})[0].text)
            Yellows     .append(row.findAll('td', {'class': 'tbl-y'})[0].text)
            Reds        .append(row.findAll('td', {'class': 'tbl-rc'})[0].text)
            Matches     .append(row.findAll('td', {'class': 'tbl-mp'})[0].text)

        df = pd.DataFrame({
                'Country': Countries,
                'CountryCode':CountryCodes,
                'YellowCards': Yellows,
                'RedCards' : Reds,
                'MatchesPlayed': Matches
        })
        
        directory = PATH + parse_names(token[17:]) + 'statistics/'
        df.to_csv(directory + 'team_top_cards.csv', index=False)
        
team_top_cards()

# %% [markdown]
# # 2. Matches

# %%
"""Data to be extracted: Home team, Away team, Scores, Attendance, Penalty, City, Date"""
def get_match_details():
    for token in tokens:
        URL = 'http://www.fifa.com' + token + 'matches/'
        HomeTeams   = []
        HomeCodes   = []
        AwayTeams   = []
        AwayCodes   = []
        HomeScore   = []
        AwayScore   = []
        Attendance  = []
        Description = []
        City        = []
        Date        = []
        Penalty     = []
        Links       = []
        r = requests.get(URL)
        soup = BeautifulSoup(r.text, 'html.parser')
        
        """Collect all match reports"""
        match_reports_link = []
        for matches in soup.findAll('div', {'class': 'match-list-date anchor'}):
            for link in matches.findAll('a'):
                match_reports_link.append('https://www.fifa.com' + link['href'])
        
        """Start to scrape"""
        for link in match_reports_link:
            Links.append(link)
            req = requests.get(link)
            sou = BeautifulSoup(req.text, 'html.parser')
            penalty = ''
            "Need to know this is a group match or final or semi final...."
            description = sou.findAll('div', {'class': 'mh-i-round'})[0].text
            Description.append(description)
            if ('Group match' in description or 'First stage' in description):
                Penalty.append('')
            else:
                "If this is a knockout match, so is there a penalty at the end ?"
                reasonwin = sou.findAll('span', {'class': 'text-reasonwin'})[0].text
                if 'penalties' in reasonwin:
                    a = reasonwin.split('(')
                    a = a[1].split(')')
                    penalty = a[0]
                    Penalty.append(a[0])
                else:
                    Penalty.append('')
        
        
            home_infos = sou.findAll('div', {'class': 't home'})[0]
            home_name = home_infos.findAll('span', {'class': 't-nText '})
            if (home_name):
                hname = home_name[0].text
            else :
                hname = home_infos.findAll('span', {'class': 't-nText kern'})[0].text
            hcode = home_infos.findAll('span', {'class': 't-nTri'})[0].text
            
            away_infos = sou.findAll('div', {'class': 't away'})[0]
            away_name = away_infos.findAll('span', {'class': 't-nText '})
            if (away_name):
                aname = away_name[0].text
            else :
                aname = away_infos.findAll('span', {'class': 't-nText kern'})[0].text
            acode = away_infos.findAll('span', {'class': 't-nTri'})[0].text
    
    
            "Team codes"
            HomeCodes.append(hcode)
            AwayCodes.append(acode)
            
            "Team names"
            if 'Ivoire' in hname:
                hname = 'Ivory Coast'
            if 'Ivoire' in aname:
                aname = 'Ivory Coast'
            HomeTeams.append(hname)
            AwayTeams.append(aname)

            "Scores"
            [home, away] = sou.findAll('span', {'class': 's-scoreText'})[0].text.split('-')
            home = str(home)
            away = str(away)
            if penalty != '':
                penalty = penalty.split('-')
                home += '(' + penalty[0] +')'
                away += '(' + penalty[1] +')'
            HomeScore.append(home)
            AwayScore.append(away)
            
            """Extra infos: Attendances are not available for 2010 and 2014"""
            if ('brazil2014' in token or 'southafrica2010' in token):
                date = sou.find('div', attrs={'class':'mh-i-datetime'})
                Date.append(date.text.split('-')[0][:-1])
                city = sou.find('span', attrs={'class':'mh-i-venue'})
                City.append(city.text)
                "Attendance cannot be extracted from FIFA.com"
                if ('brazil2014' in token): # Average from FIFA.com
                    Attendance.append('52918')
                else :
                    Attendance.append('49669')
            else :
                table = sou.find('table', attrs={'class':'table match-data'})
                table_body = table.find('tbody')
                row = table_body.find_all('tr')[0]
                cols = row.find_all('td')
                cols = [ele.text.strip() for ele in cols]
                # cols = ['26 June 2006', 'Cologne /FIFA World Cup Stadium, Cologne', '21:00', '45000']
                Date.append(cols[0])
                City.append(cols[1].split('/')[0][:-1])
                Attendance.append(cols[-1])
                
                
        df = pd.DataFrame({
              'HomeTeam'   :  HomeTeams ,
              'HomeCode'   :  HomeCodes ,
              'AwayTeam'   :  AwayTeams ,
              'AwayCode'   :  AwayCodes ,
              'HomeScore'  :  HomeScore ,
              'AwayScore'  :  AwayScore ,
              'Attendance' :  Attendance,
              'Description':  Description,
              'City'       :  City      ,
              'Date'       :  Date   ,
              'Penalty'    :  Penalty,
              'MatchReport':  Links
        })
        
        directory = PATH + parse_names(token[17:]) + 'matches/'
        df.to_csv(directory + 'matches.csv', index=False)
        
get_match_details()

# %%
df = pd.read_csv(PATH + '/2014--brazil/matches/matches.csv')
df
# Out:
#     Attendance AwayCode AwayScore                AwayTeam  \
# 0        52918      CRO         1                 Croatia
# 1        52918      CMR         0                Cameroon
# 2        52918      NED         5             Netherlands
# 3        52918      AUS         1               Australia
# 4        52918      GRE         0                  Greece
# 5        52918      CRC         3              Costa Rica
# 6        52918      ITA         2                   Italy
# 7        52918      JPN         1                   Japan
# 8        52918      ECU         1                 Ecuador
# 9        52918      HON         0                Honduras
# 10       52918      BIH         1  Bosnia and Herzegovina
# 11       52918      POR         0                Portugal
# 12       52918      NGA         0                 Nigeria
# 13       52918      USA         2                     USA
# 14       52918      ALG         1                 Algeria
# 15       52918      MEX         0                  Mexico
# 16       52918      KOR         1          Korea Republic
# 17       52918      NED         3             Netherlands
# 18       52918      CHI         2                   Chile
# 19       52918      CRO         4                 Croatia
# 20       52918      CIV         1             Ivory Coast
# 21       52918      ENG         1                 England
# 22       52918      GRE         0                  Greece
# 23       52918      CRC         1              Costa Rica
# 24       52918      FRA         5                  France
# 25       52918      ECU         2                 Ecuador
# 26       52918      IRN         0                    Iran
# 27       52918      GHA         2                   Ghana
# 28       52918      BIH         0  Bosnia and Herzegovina
# 29       52918      RUS         0                  Russia
# ..         ...      ...       ...                     ...
# 34       52918      BRA         4                  Brazil
# 35       52918      MEX         3                  Mexico
# 36       52918      URU         1                 Uruguay
# 37       52918      ENG         0                 England
# 38       52918      COL         4                Colombia
# 39       52918      CIV         1             Ivory Coast
# 40       52918      ARG         3               Argentina
# 41       52918      IRN         1                    Iran
# 42       52918      SUI         3             Switzerland
# 43       52918      FRA         0                  France
# 44       52918      GER         1                 Germany
# 45       52918      GHA         1                   Ghana
# 46       52918      BEL         1                 Belgium
# 47       52918      RUS         1                  Russia
# 48       52918      CHI     1( 2)                   Chile
# 49       52918      URU         0                 Uruguay
# 50       52918      MEX         1                  Mexico
# 51       52918      GRE     1( 3)                  Greece
# 52       52918      NGA         0                 Nigeria
# 53       52918      ALG         1                 Algeria
# 54       52918      SUI         0             Switzerland
# 55       52918      USA         1                     USA
# 56       52918      GER         1                 Germany
# 57       52918      COL         1                Colombia
# 58       52918      BEL         0                 Belgium
# 59       52918      CRC     0( 3)              Costa Rica
# 60       52918      GER         7                 Germany
# 61       52918      ARG     0( 4)               Argentina
# 62       52918      NED         3             Netherlands
# 63       52918      ARG         0               Argentina
#
#                      City         Date               Description HomeCode  \
# 0        Sao Paulo  (BRA)  12 Jun 2014     First stage - Group A      BRA
# 1            Natal  (BRA)  13 Jun 2014     First stage - Group A      MEX
# 2          Salvador (BRA)  13 Jun 2014     First stage - Group B      ESP
# 3           Cuiaba  (BRA)  13 Jun 2014     First stage - Group B      CHI
# 4   Belo Horizonte  (BRA)  14 Jun 2014     First stage - Group C      COL
# 5        Fortaleza  (BRA)  14 Jun 2014     First stage - Group D      URU
# 6           Manaus  (BRA)  14 Jun 2014     First stage - Group D      ENG
# 7           Recife  (BRA)  14 Jun 2014     First stage - Group C      CIV
# 8         Brasilia  (BRA)  15 Jun 2014     First stage - Group E      SUI
# 9     Porto Alegre  (BRA)  15 Jun 2014     First stage - Group E      FRA
# 10  Rio De Janeiro  (BRA)  15 Jun 2014     First stage - Group F      ARG
# 11         Salvador (BRA)  16 Jun 2014     First stage - Group G      GER
# 12        Curitiba  (BRA)  16 Jun 2014     First stage - Group F      IRN
# 13           Natal  (BRA)  16 Jun 2014     First stage - Group G      GHA
# 14  Belo Horizonte  (BRA)  17 Jun 2014     First stage - Group H      BEL
# 15       Fortaleza  (BRA)  17 Jun 2014     First stage - Group A      BRA
# 16          Cuiaba  (BRA)  17 Jun 2014     First stage - Group H      RUS
# 17    Porto Alegre  (BRA)  18 Jun 2014     First stage - Group B      AUS
# 18  Rio De Janeiro  (BRA)  18 Jun 2014     First stage - Group B      ESP
# 19          Manaus  (BRA)  18 Jun 2014     First stage - Group A      CMR
# 20        Brasilia  (BRA)  19 Jun 2014     First stage - Group C      COL
# 21       Sao Paulo  (BRA)  19 Jun 2014     First stage - Group D      URU
# 22           Natal  (BRA)  19 Jun 2014     First stage - Group C      JPN
# 23          Recife  (BRA)  20 Jun 2014     First stage - Group D      ITA
# 24         Salvador (BRA)  20 Jun 2014     First stage - Group E      SUI
# 25        Curitiba  (BRA)  20 Jun 2014     First stage - Group E      HON
# 26  Belo Horizonte  (BRA)  21 Jun 2014     First stage - Group F      ARG
# 27       Fortaleza  (BRA)  21 Jun 2014     First stage - Group G      GER
# 28          Cuiaba  (BRA)  21 Jun 2014     First stage - Group F      NGA
# 29  Rio De Janeiro  (BRA)  22 Jun 2014     First stage - Group H      BEL
# ..                    ...          ...                       ...      ...
# 34        Brasilia  (BRA)  23 Jun 2014     First stage - Group A      CMR
# 35          Recife  (BRA)  23 Jun 2014     First stage - Group A      CRO
# 36           Natal  (BRA)  24 Jun 2014     First stage - Group D      ITA
# 37  Belo Horizonte  (BRA)  24 Jun 2014     First stage - Group D      CRC
# 38          Cuiaba  (BRA)  24 Jun 2014     First stage - Group C      JPN
# 39       Fortaleza  (BRA)  24 Jun 2014     First stage - Group C      GRE
# 40    Porto Alegre  (BRA)  25 Jun 2014     First stage - Group F      NGA
# 41         Salvador (BRA)  25 Jun 2014     First stage - Group F      BIH
# 42          Manaus  (BRA)  25 Jun 2014     First stage - Group E      HON
# 43  Rio De Janeiro  (BRA)  25 Jun 2014     First stage - Group E      ECU
# 44          Recife  (BRA)  26 Jun 2014     First stage - Group G      USA
# 45        Brasilia  (BRA)  26 Jun 2014     First stage - Group G      POR
# 46       Sao Paulo  (BRA)  26 Jun 2014     First stage - Group H      KOR
# 47        Curitiba  (BRA)  26 Jun 2014     First stage - Group H      ALG
# 48  Belo Horizonte  (BRA)  28 Jun 2014               Round of 16      BRA
# 49  Rio De Janeiro  (BRA)  28 Jun 2014               Round of 16      COL
# 50       Fortaleza  (BRA)  29 Jun 2014               Round of 16      NED
# 51          Recife  (BRA)  29 Jun 2014               Round of 16      CRC
# 52        Brasilia  (BRA)  30 Jun 2014               Round of 16      FRA
# 53    Porto Alegre  (BRA)  30 Jun 2014               Round of 16      GER
# 54       Sao Paulo  (BRA)  01 Jul 2014               Round of 16      ARG
# 55         Salvador (BRA)  01 Jul 2014               Round of 16      BEL
# 56  Rio De Janeiro  (BRA)  04 Jul 2014            Quarter-finals      FRA
# 57       Fortaleza  (BRA)  04 Jul 2014            Quarter-finals      BRA
# 58        Brasilia  (BRA)  05 Jul 2014            Quarter-finals      ARG
# 59         Salvador (BRA)  05 Jul 2014            Quarter-finals      NED
# 60  Belo Horizonte  (BRA)  08 Jul 2014               Semi-finals      BRA
# 61       Sao Paulo  (BRA)  09 Jul 2014               Semi-finals      NED
# 62        Brasilia  (BRA)  12 Jul 2014  Play-off for third place      BRA
# 63  Rio De Janeiro  (BRA)  13 Jul 2014                     Final      GER
#
#    HomeScore                HomeTeam  \
# 0          3                  Brazil
# 1          1                  Mexico
# 2          1                   Spain
# 3          3                   Chile
# 4          3                Colombia
# 5          1                 Uruguay
# 6          1                 England
# 7          2             Ivory Coast
# 8          2             Switzerland
# 9          3                  France
# 10         2               Argentina
# 11         4                 Germany
# 12         0                    Iran
# 13         1                   Ghana
# 14         2                 Belgium
# 15         0                  Brazil
# 16         1                  Russia
# 17         2               Australia
# 18         0                   Spain
# 19         0                Cameroon
# 20         2                Colombia
# 21         2                 Uruguay
# 22         0                   Japan
# 23         0                   Italy
# 24         2             Switzerland
# 25         1                Honduras
# 26         1               Argentina
# 27         2                 Germany
# 28         1                 Nigeria
# 29         1                 Belgium
# ..       ...                     ...
# 34         1                Cameroon
# 35         1                 Croatia
# 36         0                   Italy
# 37         0              Costa Rica
# 38         1                   Japan
# 39         2                  Greece
# 40         2                 Nigeria
# 41         3  Bosnia and Herzegovina
# 42         0                Honduras
# 43         0                 Ecuador
# 44         0                     USA
# 45         2                Portugal
# 46         0          Korea Republic
# 47         1                 Algeria
# 48     1(3 )                  Brazil
# 49         2                Colombia
# 50         2             Netherlands
# 51     1(5 )              Costa Rica
# 52         2                  France
# 53         2                 Germany
# 54         1               Argentina
# 55         2                 Belgium
# 56         0                  France
# 57         2                  Brazil
# 58         1               Argentina
# 59     0(4 )             Netherlands
# 60         1                  Brazil
# 61     0(2 )             Netherlands
# 62         0                  Brazil
# 63         1                 Germany
#
#                                           MatchReport Penalty
# 0   https://www.fifa.com/worldcup/matches/round=25...     NaN
# 1   https://www.fifa.com/worldcup/matches/round=25...     NaN
# 2   https://www.fifa.com/worldcup/matches/round=25...     NaN
# 3   https://www.fifa.com/worldcup/matches/round=25...     NaN
# 4   https://www.fifa.com/worldcup/matches/round=25...     NaN
# 5   https://www.fifa.com/worldcup/matches/round=25...     NaN
# 6   https://www.fifa.com/worldcup/matches/round=25...     NaN
# 7   https://www.fifa.com/worldcup/matches/round=25...     NaN
# 8   https://www.fifa.com/worldcup/matches/round=25...     NaN
# 9   https://www.fifa.com/worldcup/matches/round=25...     NaN
# 10  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 11  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 12  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 13  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 14  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 15  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 16  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 17  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 18  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 19  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 20  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 21  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 22  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 23  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 24  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 25  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 26  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 27  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 28  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 29  https://www.fifa.com/worldcup/matches/round=25...     NaN
# ..                                                ...     ...
# 34  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 35  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 36  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 37  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 38  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 39  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 40  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 41  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 42  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 43  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 44  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 45  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 46  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 47  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 48  https://www.fifa.com/worldcup/matches/round=25...   3 - 2
# 49  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 50  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 51  https://www.fifa.com/worldcup/matches/round=25...   5 - 3
# 52  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 53  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 54  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 55  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 56  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 57  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 58  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 59  https://www.fifa.com/worldcup/matches/round=25...   4 - 3
# 60  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 61  https://www.fifa.com/worldcup/matches/round=25...   2 - 4
# 62  https://www.fifa.com/worldcup/matches/round=25...     NaN
# 63  https://www.fifa.com/worldcup/matches/round=25...     NaN
#
# [64 rows x 12 columns]

# %% [markdown]
# # 3. Teams

# %%
def get_player_infos():
    for token in tokens:
        URL = 'http://www.fifa.com' + token + 'teams/'
        Country = []
        CountryCode = []
        Player = []
        Age = []
        Position = []
        r = requests.get(URL)
        soup = BeautifulSoup(r.text, 'html.parser')
        
        all_teams_link = soup.findAll('div', {'class': 'team-map'})[0].findAll('a', {'class':'map-item'})
        for link in all_teams_link:
            countryCode = link['id']
            country = link['title']
            if 'Ivoire' in country:
                country = 'Ivory Coast'
            string = link['href'].split('/')
            edition = string[3][-4:] #year
            teamID  = string[5][5:]  #teamID
            squad_link = 'http://www.fifa.com/worldcup/archive/edition=' + edition + '/library/teams/team=' + teamID + '/_players/_players_list.html'
            
            req = requests.get(squad_link)
            sou = BeautifulSoup(req.text, 'html.parser')
            
            if ('brazil2014' in token):
                squads = sou.findAll('div', {'class': 'p p-i p-i-prt-1'})
            else:
                squads = sou.findAll('div', {'class': 'p p-i-no'})
            for s in squads:
                Country.append(country)
                CountryCode.append(countryCode)
                Player.append(s['data-player-name'])
                Position.append(s.findAll('span', {'class': 'p-i-fieldpos'})[0].text)
                Age.append(s.findAll('div', {'class': 'p-ag age'})[0].text)
        
        df = pd.DataFrame({
              'Country'       :  Country ,
              'CountryCode'   :  CountryCode ,
              'Player'       :  Player ,
              'Age'         :  Age ,
              'Position'   :  Position
        })
        
        directory = PATH + parse_names(token[17:]) + 'teams/'
        df.to_csv(directory + 'players.csv', index=False)
        
get_player_infos()

# %%
a = 5

# %%
str(a)
# Out:
# '5'
